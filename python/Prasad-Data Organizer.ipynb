# %%
import csv
import pandas as pd

# %%
df= pd.read_csv('data/transcription.csv')

# %%
df.head()
# Out:
#   Transcriber Block # Parcel # Ward # Box #          Street number  \
# 0         NaN       1        2      4    56  198\n198 1/2\n198-200
# 1         NaN       1        3      4    56                202-208
# 2         NaN       1        4      4    56                90\n196
# 3         NaN       1        5      4    56                     94
# 4         NaN       1        6      4    56                     98
#
#                 Street address     Land use  \
# 0                 Hillard Ave.   Commercial
# 1                 Hillard Ave.   Commercial
# 2  Asheland Ave.\nHillard Ave.   Commercial
# 3                Asheland Ave.  Residential
# 4                Asheland Ave.   Commercial
#
#   Previous Transfer of deed Event Date  \
# 0                                    -
# 1                           08/01/1967
# 2                           04/04/1940
# 3                           04/28/1934
# 4                           12/24/1964
#
#            Previous Transfer of deed People Involved  \
# 0  Bessie S. Kalogerakis\n\nAmelia K. Kalogerakis...
# 1  W.S. Harrison\nBeulah L. Harrison\n\nCharles R...
# 2  Charles G. Lee, Sr.\n\nCharles G. Lee, Jr.\nH....
# 3  John E. Smathers\nEtta C. Smathers\n\nThelma S...
# 4  C.A. Yarbrough\nSarah M Yarbrough\n\nHarry's C...
#
#              ...              \
# 0            ...
# 1            ...
# 2            ...
# 3            ...
# 4            ...
#
#                             Decision People Involved           Decision Role  \
# 0  \nAmelia K. Kalogerakis\nEva K. Cleraderas\nSt...    Owner\n\n\nPurchaser
# 1             Charles R. Stinnette Co., Inc.\n\nHACA      Owner\n\nPurchaser
# 2  William I. Lee\nZyphin J. Lee\nH. Kenneth Lee\...  Owner\n\n\n\nPurchaser
# 3  Thelma Smathers Johnson\nElizabeth Pauline Sma...    Owner\n\n\nPurchaser
# 4   Harry's Cadillac-Pontiac Company, Inc.\n\nHACA\n      Owner\n\nPurchaser
#
#    Award Date Award Amount Money Tenant Vacated Date Tenant Agreement Date  \
# 0           -                  -                   -                     -
# 1  07/16/1971              21600                   -                     -
# 2  08/17/1972              46000                   -                     -
# 3           -                  -                   -                     -
# 4           -                  -                   -                     -
#
#   Tenant Cost Tenant Name Previous owner\nor\nTenant  \
# 0           -           -                          -
# 1           -           -                          -
# 2           -           -                          -
# 3           -           -                          -
# 4           -           -                          -
#
#   End of Case Finalized Date
# 0                 06/06/1969
# 1                  06/171971
# 2                 07/13/1972
# 3                 05/29/1974
# 4                 10/09/1974
#
# [5 rows x 35 columns]

# %%
parcels=df[['Block #', 'Parcel #','Ward #','Land use']]

# %%
parcels=parcels[parcels['Block #'].str.contains("Spring")==False]

# %%
parcels=parcels[parcels['Block #'].str.contains("  ")==False]

# %%
parcels['Block #'].dtypes
# Out:
# dtype('O')

# %%
parcels.insert(0, 'Parcel_ID', range(0,0+len(parcels)))

# %%
parcels.head()
# Out:
#    Parcel_ID Block # Parcel # Ward #     Land use
# 0          0       1        2      4   Commercial
# 1          1       1        3      4   Commercial
# 2          2       1        4      4   Commercial
# 3          3       1        5      4  Residential
# 4          4       1        6      4   Commercial

# %%
parcels.to_csv('Parcels')

# %%
parcels
# Out:
#      Parcel_ID Block # Parcel # Ward #                 Land use
# 0            0       1        2      4               Commercial
# 1            1       1        3      4               Commercial
# 2            2       1        4      4               Commercial
# 3            3       1        5      4              Residential
# 4            4       1        6      4               Commercial
# 5            5       1        7      4               Commercial
# 6            6       1        8      4              Residential
# 7            7       1        9      4               Commercial
# 8            8       1       10      4               Commercial
# 9            9       1       11      4               Commercial
# 10          10       1       12      4  Residential\nCommercial
# 11          11       1       13      4               Commercial
# 12          12       1      13A      4               Commercial
# 13          13       1       14      4  Commercial\nResidential
# 14          14       1       15      4               Commercial
# 15          15       1       16      4              Residential
# 16          16       1       17      4              Residential
# 17          17       1       18      4              Residential
# 18          18       1       19      4               Commercial
# 19          19       1       20      4               Commercial
# 20          20       1       21      4               Commercial
# 21          21       1       22      4               Commercial
# 22          22       1       24      4               Commercial
# 23          23       1       25      4               Commercial
# 24          24       1       27      4              Residential
# 25          25       1       28      4               Commercial
# 26          26       1       29      4               Commercial
# 27          27       1       30      4               Commercial
# 28          28       1       31      4              Residential
# 29          29       1       32      4               Commercial
# ..         ...     ...      ...    ...                      ...
# 525        512      53        2      4              Residential
# 526        513      50       18      4              Residential
# 527        514      50       19      4              Residential
# 528        515       4       24      4               Commercial
# 529        516       4       23      4               Commercial
# 530        517       5       16      4              Residential
# 531        518       5       13      4              Residential
# 532        519       5       12      4              Residential
# 533        520      53      15B      4              Residential
# 534        521      53        8      4              Residential
# 535        522      55       40      4              Residential
# 536        523      55       41      4                   Church
# 537        524       5        6      4              Residential
# 538        525       5        9      4              Residential
# 539        526       5       10      4              Residential
# 540        527       5       11      4              Residential
# 541        528       4        6      4               Commercial
# 542        529       4        9      4              Residential
# 543        530       4       21      4              Residential
# 544        531       4       22      4               Commercial
# 545        532      53        9      4              Residential
# 546        533      55        1      4              Residential
# 547        534       4        5      4              Residential
# 549        535       6        8      4              Residential
# 550        536       5       21      4              Residential
# 551        537       5       21      4              Residential
# 552        538       5       21      4              Residential
# 553        539       6       38      4              Residential
# 554        540       6       38      4              Residential
# 555        541       6       38      4              Residential
#
# [542 rows x 5 columns]

# %%
parcel_id=parcels[['Parcel_ID']]

# %%
addresses= df[['Street number', 'Street address']]

# %%
addresses.insert(0,'ID',range(0,0+len(addresses)))

# %%
addresses.head()
# Out:
#    ID          Street number               Street address
# 0   0  198\n198 1/2\n198-200                 Hillard Ave.
# 1   1                202-208                 Hillard Ave.
# 2   2                90\n196  Asheland Ave.\nHillard Ave.
# 3   3                     94                Asheland Ave.
# 4   4                     98                Asheland Ave.

# %%
addresses['Street number']= addresses['Street number'].str.extract('(\n)', expand=False)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
addresses
# Out:
#       ID          Street number                            Street address  \
# 0      0  198\n198 1/2\n198-200                              Hillard Ave.
# 1      1                202-208                              Hillard Ave.
# 2      2                90\n196               Asheland Ave.\nHillard Ave.
# 3      3                     94                             Asheland Ave.
# 4      4                     98                             Asheland Ave.
# 5      5              110 - 112                             Asheland Ave.
# 6      6                    114                             Asheland Ave.
# 7      7                    122                             Asheland Ave.
# 8      8            Rear of 114                             Asheland Ave.
# 9      9                132 1/2                             Asheland Ave.
# 10    10                    132                             Asheland Ave.
# 11    11                    136                             Asheland Ave.
# 12    12                    136                             Asheland Ave.
# 13    13                      2                               Wallack St.
# 14    14                      5                               Wallack St.
# 15    15                      7                               Wallack St.
# 16    16                      9                               Wallack St.
# 17    17                     11                               Wallack St.
# 18    18                     15                               Wallack St.
# 19    19                     17                               Wallack St.
# 20    20                     23                               Wallack St.
# 21    21                     23                               Wallack St.
# 22    22                     55                               Wallack St.
# 23    23                 47 1/2                               Wallack St.
# 24    24                     77                               Wallack St.
# 25    25                     87                               Wallack St.
# 26    26             Rear of 87                               Wallack St.
# 27    27            Rear of 102                               Wallack St.
# 28    28                    102                               Wallack St.
# 29    29                    101                               Wallack St.
# ..   ...                    ...                                       ...
# 526  526                    N/S  N/E Cor. Southern St. \nand Graham Place
# 527  527                    N/S                           Southern Street
# 528  528                     99                                  Asheland
# 529  529                    105                                  Asheland
# 530  530                     33                             Silver Street
# 531  531                    NaN                      Near 176 S. Grove Rd
# 532  532               178 1/2                              S. Grove Road
# 533  533                    493                    S. French Broad Avenue
# 534  534                494-496                              Depot Street
# 535  535                    113                              Black Street
# 536  536                    103                              Black Street
# 537  537                  168.5                        South Grove Street
# 538  538                    174            Rear of 174 South Grove Street
# 539  539                    174            Rear of 174 South Grove Street
# 540  540                    192                        South Grove Street
# 541  541                    NaN                                       NaN
# 542  542                    118                        South Grove Street
# 543  543                    113                             Asheland Ave.
# 544  544                    111                             Asheland Ave.
# 545  545                    502                                 Depot St.
# 546  546                     82                            Livingston St.
# 547  547                    100                        South Grove Street
# 548  548            Spring 2018                               Spring 2018
# 549  549                     88                   South French Broad Ave.
# 550  550                      7                                Silver St.
# 551  551                      7                                Silver St.
# 552  552                      7                                Silver St.
# 553  553                      8                                DeWitt St.
# 554  554                      8                                DeWitt St.
# 555  555                      8                                DeWitt St.
#
#              new
# 0            198
# 1        202-208
# 2             90
# 3             94
# 4             98
# 5      110 - 112
# 6            114
# 7            122
# 8    Rear of 114
# 9        132 1/2
# 10           132
# 11           136
# 12           136
# 13             2
# 14             5
# 15             7
# 16             9
# 17            11
# 18            15
# 19            17
# 20            23
# 21            23
# 22            55
# 23        47 1/2
# 24            77
# 25            87
# 26    Rear of 87
# 27   Rear of 102
# 28           102
# 29           101
# ..           ...
# 526          N/S
# 527          N/S
# 528           99
# 529          105
# 530           33
# 531          NaN
# 532     178 1/2
# 533          493
# 534      494-496
# 535          113
# 536          103
# 537        168.5
# 538          174
# 539          174
# 540          192
# 541          NaN
# 542          118
# 543          113
# 544          111
# 545          502
# 546           82
# 547          100
# 548  Spring 2018
# 549           88
# 550            7
# 551            7
# 552            7
# 553            8
# 554            8
# 555            8
#
# [556 rows x 4 columns]
